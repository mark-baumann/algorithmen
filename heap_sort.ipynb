# %% [markdown]
# # 🌲 Heap Sort
#
# **O(n log n)** — in-place, nicht stabil.
#
# ---
# ## 📚 Idee
# Baue einen Max-Heap auf, entnimm wiederholt das größte Element und stelle die Heap-Eigenschaft wieder her.
#
# > 💡 **Google Colab:** Datei → In Drive speichern → mit GPU/TPU ausführen.

# %%
def _heapify(arr: list, n: int, i: int) -> None:
    largest = i
    left, right = 2 * i + 1, 2 * i + 2
    if left < n and arr[left] > arr[largest]:
        largest = left
    if right < n and arr[right] > arr[largest]:
        largest = right
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        _heapify(arr, n, largest)

def heap_sort(arr: list) -> list:
    """O(n log n) — in-place, nicht stabil."""
    arr = arr.copy()
    n = len(arr)
    for i in range(n // 2 - 1, -1, -1):
        _heapify(arr, n, i)
    for i in range(n - 1, 0, -1):
        arr[0], arr[i] = arr[i], arr[0]
        _heapify(arr, i, 0)
    return arr

arr = [64, 34, 25, 12, 22, 11, 90]
print(f"Original: {arr}")
print(f"Heap:     {heap_sort(arr)}")

# %% [markdown]
# ## 🎯 Zusammenfassung
#
# | Eigenschaft | Wert |
# |------------|------|
# | Laufzeit (avg) | O(n log n) |
# | Laufzeit (worst) | O(n log n) |
# | Stabil | ❌ |
# | In-Place | ✅ |
